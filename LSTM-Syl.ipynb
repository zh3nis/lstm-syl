# %%
import numpy as np
import tensorflow as tf
import time
from pyphen import Pyphen
from hyphen import Hyphenator

# %%
# Global hyperparameters
batch_size = 20
max_grad_norm = 5
lr_decay = 0.5
learning_rate = 1.0
init_scale = 0.05

# LSTM hyperparameters
num_steps = 35
hidden_size = 300
num_layers = 2
keep_prob = 0.5

# Syllable LSTM hyperparameters
#syl_emb_dim = 126
#syl_hidden_size = 190
#max_word_len - number of steps (syllables) to unroll the syllable LSTM for, will be defined based on training data

# %%
# possibles languages: ptb, fr, es, de, cs, ru ('ptb' means English PTB dataset)
lang = 'fr'

pyphen_lang = {'ptb': 'en_US',
               'fr': 'fr_FR',
               'es': 'es',
               'de': 'de_DE',
               'cs': 'cs_CZ',
               'ru': 'ru_RU'}

if lang == 'ptb': 
  word_data = open('data/'+lang+'/train.txt', 'r').read().replace('\n', '<eos>').split()
else:
  word_data = open('data/'+lang+'/train.txt', 'r').read().replace('\n', ' ').split()

words = list(set(word_data))
word_data_size, word_vocab_size = len(word_data), len(words)
print('data has %d words, %d unique' % (word_data_size, word_vocab_size))

word_to_ix = { word:i for i,word in enumerate(words) }
ix_to_word = { i:word for i,word in enumerate(words) }

def get_word_raw_data(input_file):
  if lang == 'ptb':
    data = open(input_file, 'r').read().replace('\n', '<eos>').split()
  else:
    data = open(input_file, 'r').read().replace('\n', ' ').split()
  return [word_to_ix[w] for w in data]

train_raw_data = get_word_raw_data('data/'+lang+'/train.txt')
valid_raw_data = get_word_raw_data('data/'+lang+'/valid.txt')
test_raw_data = get_word_raw_data('data/'+lang+'/test.txt')
# Out:
# data has 1000008 words, 24984 unique

# %%
hyphenator = Pyphen(lang=pyphen_lang[lang])

def my_syllables(word):
  return hyphenator.inserted(word).split('-')

syllables = set()
word_lens_in_syl = []

for word in words:
  syls = my_syllables(word)
  word_lens_in_syl.append(len(syls))
  for syl in syls:
    syllables.add(syl)

syls_list = list(syllables)
syl_vocab_size = len(syls_list)

max_word_len = int(np.percentile(word_lens_in_syl, 97))
print('data has %d unique syllables' % syl_vocab_size)
print('max word length in syllables is set to', max_word_len)

#one more fake syllable for zero-padding
zero_pad_syl = ' '
syls_list.insert(0, zero_pad_syl)
syl_vocab_size += 1

syl_to_ix = { syl:i for i,syl in enumerate(syls_list) }
ix_to_syl = { i:syl for i,syl in enumerate(syls_list) }

ratio = 2

def get_syl_hyperparams(total):
  a = 4 * (ratio + ratio * ratio)
  b = syl_vocab_size + 4 * ratio + 4 * ratio * hidden_size
  c = 4 * (hidden_size * hidden_size + hidden_size) +\
      4 * (hidden_size * hidden_size + hidden_size * hidden_size + hidden_size) +\
      hidden_size * word_vocab_size + word_vocab_size - total
  neg, pos = np.roots([a, b, c])
  return (int(round(pos)), int(round(ratio * pos)))

total = {'ptb': 5310115,
         'fr':  9820689,
         'es': 10430455,
         'de': 13317075,
         'cs': 16251327,
         'ru': 21353640}

syl_emb_dim, syl_hidden_size = get_syl_hyperparams(total[lang])
print('Syllable embedding size: ', syl_emb_dim)
print('Syllable LSTM hidden size: ', syl_hidden_size)
# Out:
# data has 9328 unique syllables
# max word length in syllables is set to 5
# Syllable embedding size:  88
# Syllable LSTM hidden size:  176

# %%
def word_ix_to_syl_ixs(word_ix):
  word = ix_to_word[word_ix]
  word_in_syls = my_syllables(word)
  if len(word_in_syls) > max_word_len:
    del word_in_syls[max_word_len:]
  else:
    word_in_syls += [zero_pad_syl] * (max_word_len - len(word_in_syls))
  return [syl_to_ix[syl] for syl in word_in_syls]

constitution = {'ptb': 'constitution', 
                'fr': 'constitution', 
                'de': 'verfassung', 
                'cs': 'ústava',
                'es': 'constitución',
                'ru': 'конституция'}
print('-'.join(ix_to_syl[syl_ix] for syl_ix in word_ix_to_syl_ixs(word_to_ix[constitution[lang]])))
# Out:
# consti-tu-tion- -

# %%
class batch_producer(object):
  def __init__(self, raw_data, batch_size, num_steps):
    self.raw_data = raw_data
    self.batch_size = batch_size
    self.num_steps = num_steps
    
    self.batch_len = len(self.raw_data) // self.batch_size
    self.data = np.reshape(self.raw_data[0 : self.batch_size * self.batch_len],
                           (self.batch_size, self.batch_len))
    
    self.epoch_size = (self.batch_len - 1) // self.num_steps
    self.i = 0
  
  def __next__(self):
    if self.i < self.epoch_size:
      # batch_x and batch_y are of shape [batch_size, num_steps]
      batch_x = self.data[::, self.i * self.num_steps : (self.i + 1) * self.num_steps : ]
      batch_y = self.data[::, self.i * self.num_steps + 1 : (self.i + 1) * self.num_steps + 1 : ]
      self.i += 1
      return (batch_x, batch_y)
    else:
      raise StopIteration()

  def __iter__(self):
    return self

# %%
class Model:
  
  syl_embedding = tf.get_variable("syl_embedding", [syl_vocab_size, syl_emb_dim], dtype=tf.float32,
                                  initializer=tf.random_uniform_initializer(-init_scale, init_scale))
  syl_lstm_cell = tf.nn.rnn_cell.LSTMCell(syl_hidden_size, forget_bias=0.0)
  cell = tf.nn.rnn_cell.LSTMCell(hidden_size, forget_bias=0.0)
  
  def __init__(self, batch_size, need_reuse=False):
    self.x = tf.placeholder(tf.int32, [batch_size, num_steps, max_word_len])
    self.y = tf.placeholder(tf.int32, [batch_size, num_steps])
    
    words_embedded = tf.nn.embedding_lookup(self.syl_embedding, self.x)
    words_emb_as_list = tf.unpack(words_embedded, axis=1)

    syl_init_state = self.syl_lstm_cell.zero_state(batch_size, dtype=tf.float32)

    lstm_input = []
    reuse_syl_lstm = need_reuse
    for word_emb in words_emb_as_list:
      #list of max_word_len elements of [batch_size, syl_emb_dim]
      word_in_syls = tf.unpack(word_emb, axis=1)
      with tf.variable_scope('syl_lstm', reuse=reuse_syl_lstm):
        syl_outputs, syl_state = tf.nn.rnn(self.syl_lstm_cell, word_in_syls, dtype=tf.float32, 
                                           initial_state=syl_init_state, sequence_length=self.length(word_emb))
      lstm_input.append(syl_state.h)
      reuse_syl_lstm = True
    
    self.apply_dropout()
    self.cell = tf.nn.rnn_cell.MultiRNNCell([self.cell] * num_layers)
    
    self.init_state = self.cell.zero_state(batch_size, dtype=tf.float32)
    with tf.variable_scope('lstm_rnn', reuse=need_reuse):
      outputs, self.state = tf.nn.rnn(self.cell, lstm_input, dtype=tf.float32, initial_state=self.init_state)

    with tf.variable_scope('softmax_params', reuse=need_reuse):
      weights = tf.get_variable('weights', [hidden_size, word_vocab_size], 
                                initializer=tf.random_uniform_initializer(-init_scale, init_scale), 
                                dtype=tf.float32)
      biases = tf.get_variable('biases', [word_vocab_size], 
                               initializer=tf.random_uniform_initializer(-init_scale, init_scale),
                               dtype=tf.float32)

    output = tf.reshape(tf.concat(1, outputs), [-1, hidden_size])
    logits = tf.matmul(output, weights) + biases
    loss = tf.nn.seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.y, [-1])],
            [tf.ones([batch_size * num_steps], dtype=tf.float32)])
    self.cost = tf.reduce_sum(loss) / batch_size

  def length(self, sequence):
    used = tf.sign(tf.reduce_max(tf.abs(sequence), reduction_indices=2))
    length = tf.reduce_sum(used, reduction_indices=1)
    length = tf.cast(length, tf.int32)
    return length
  
  def apply_dropout(self):
    self.cell = tf.nn.rnn_cell.DropoutWrapper(self.cell, output_keep_prob=keep_prob)
    self.syl_lstm_cell = tf.nn.rnn_cell.DropoutWrapper(self.syl_lstm_cell, input_keep_prob=keep_prob, 
                                                       output_keep_prob=keep_prob)

# %%
class Train(Model):
  
  def __init__(self, batch_size):
    self.clear_syl_embedding_padding = tf.scatter_update(self.syl_embedding, 
                                                         [0], 
                                                         tf.constant(0.0, shape=[1, syl_emb_dim], dtype=tf.float32)
                                                        )
  
    super(Train, self).__init__(batch_size)
    
    self.lr = tf.Variable(0.0, trainable=False, dtype=tf.float32)
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars), max_grad_norm)
    optimizer = tf.train.GradientDescentOptimizer(self.lr)
    self.train_op = optimizer.apply_gradients(zip(grads, tvars),
                                              global_step=tf.contrib.framework.get_or_create_global_step())
    
    self.new_lr = tf.placeholder(tf.float32, shape=[], name="new_learning_rate")
    self.lr_update = tf.assign(self.lr, self.new_lr)

  def assign_lr(self, session, lr_value):
    session.run(self.lr_update, feed_dict={self.new_lr: lr_value})

# %%
class Eval(Model):
  
  def apply_dropout(self):
    pass

# %%
train = Train(batch_size)
valid = Eval(batch_size, need_reuse=True)
test = Eval(1, need_reuse=True)

# %%
def model_size():
  params = tf.trainable_variables()
  size = 0
  for x in params:
    sz = 1
    for dim in x.get_shape():
      sz *= dim.value
    size += sz
  return size

print('Model size is: ', model_size())

def my_model_size():
  return syl_vocab_size * syl_emb_dim +\
         4 * (syl_emb_dim * syl_hidden_size + syl_hidden_size * syl_hidden_size + syl_hidden_size) +\
         4 * (syl_hidden_size * hidden_size + hidden_size * hidden_size + hidden_size) +\
         4 * (hidden_size * hidden_size + hidden_size * hidden_size + hidden_size) +\
         hidden_size * word_vocab_size + word_vocab_size
        
print('My model size: ', my_model_size())
# Out:
# Model size is:  9821296
# My model size:  9821296

# %%
num_epochs = 35
display_freq = 200

init = tf.global_variables_initializer()
with tf.Session() as sess:
  sess.run(init)
  sess.run(train.clear_syl_embedding_padding)
  prev_perplexity = float('inf')
  
  for epoch in range(num_epochs):
    start_time = time.time()
    train.assign_lr(sess, learning_rate)
    
    iters = 0
    costs = 0
    
    train_batches = batch_producer(train_raw_data, batch_size, num_steps)
        
    training_state = None

    for batch in train_batches:
      my_x = np.empty([batch_size, num_steps, max_word_len], dtype=np.int32)

      for t in range(num_steps):
        for i in range(batch_size):
          my_x[i, t] = word_ix_to_syl_ixs(batch[0][i, t])

      if not training_state: training_state = sess.run(train.init_state)
      _, c, training_state, my_lr = sess.run([train.train_op, train.cost, train.state, train.lr],
                                             feed_dict={train.x: my_x, train.y: batch[1], 
                                                        train.init_state: training_state})
      sess.run(train.clear_syl_embedding_padding)
      
      costs += c
      if iters % (display_freq*num_steps) == 0 and iters != 0:
        print('step =', iters/num_steps, end=', ')
        print('perplexity =', np.exp(costs / iters), end=', ')
        print('learning rate =', my_lr, end=', ')
        print('speed =', round(iters * batch_size / (time.time() - start_time)), ' wps')

      iters += num_steps
    
    print('epoch ', epoch+1, end = ': ')
    print('perplexity =', np.exp(costs / iters), end=', ')
    print('learning rate =', my_lr)
    
    
    # Get validation set perplexity
    valid_costs = 0
    valid_state = None
    valid_iters = 0

    valid_batches = batch_producer(valid_raw_data, batch_size, num_steps)
    
    for valid_batch in valid_batches:
      my_valid_x = np.empty([batch_size, num_steps, max_word_len], dtype=np.int32)
      
      for t in range(num_steps):
        for i in range(batch_size):
          my_valid_x[i, t] = word_ix_to_syl_ixs(valid_batch[0][i, t])
      
      if not valid_state: valid_state = sess.run(valid.init_state)
      c, valid_state = sess.run([valid.cost, valid.state], 
                                feed_dict={valid.x: my_valid_x, valid.y: valid_batch[1], 
                                           valid.init_state: valid_state})

      valid_costs += c
      valid_iters += num_steps
    
    cur_perplexity = np.exp(valid_costs / valid_iters)
    print('Validation set perplexity =', cur_perplexity)

    if prev_perplexity - cur_perplexity < 1:
      learning_rate *= lr_decay
    prev_perplexity = cur_perplexity

    
    # Get test set perplexity
    test_costs = 0
    test_state = None
    test_iters = 0

    test_batches = batch_producer(test_raw_data, 1, num_steps)
    
    for test_batch in test_batches:
      my_test_x = np.empty([1, num_steps, max_word_len], dtype=np.int32)
      
      for t in range(num_steps):
        for i in range(1):
          my_test_x[i, t] = word_ix_to_syl_ixs(test_batch[0][i, t])

      if not test_state: test_state = sess.run(test.init_state)
      c, test_state = sess.run([test.cost, test.state], 
                                feed_dict={test.x: my_test_x, test.y: test_batch[1], 
                                           test.init_state: test_state})

      test_costs += c
      test_iters += num_steps
    
    print('Test set perplexity =', np.exp(test_costs / test_iters))
       

    print('-' * 100)
# Out:
# step = 200.0, perplexity = 1657.49222786, learning rate = 1.0, speed = 6965  wps
# step = 400.0, perplexity = 1148.66854615, learning rate = 1.0, speed = 7498  wps
# step = 600.0, perplexity = 830.312700047, learning rate = 1.0, speed = 7695  wps
# step = 800.0, perplexity = 645.592859047, learning rate = 1.0, speed = 7792  wps
# step = 1000.0, perplexity = 533.697402833, learning rate = 1.0, speed = 7846  wps
# step = 1200.0, perplexity = 455.729467602, learning rate = 1.0, speed = 7888  wps
# step = 1400.0, perplexity = 400.571106155, learning rate = 1.0, speed = 7916  wps
# epoch  1: perplexity = 392.728500068, learning rate = 1.0
# Validation set perplexity = 363.438299118
# Test set perplexity = 375.822366321
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 184.472390662, learning rate = 1.0, speed = 8010  wps
# step = 400.0, perplexity = 171.713923541, learning rate = 1.0, speed = 8042  wps
# step = 600.0, perplexity = 165.69779312, learning rate = 1.0, speed = 8054  wps
# step = 800.0, perplexity = 160.985858918, learning rate = 1.0, speed = 8060  wps
# step = 1000.0, perplexity = 157.492433475, learning rate = 1.0, speed = 8053  wps
# step = 1200.0, perplexity = 152.666452474, learning rate = 1.0, speed = 8055  wps
# step = 1400.0, perplexity = 148.323680667, learning rate = 1.0, speed = 8057  wps
# epoch  2: perplexity = 147.323085792, learning rate = 1.0
# Validation set perplexity = 292.106396136
# Test set perplexity = 302.956639665
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 132.621682149, learning rate = 1.0, speed = 8000  wps
# step = 400.0, perplexity = 125.206048136, learning rate = 1.0, speed = 8030  wps
# step = 600.0, perplexity = 123.148399036, learning rate = 1.0, speed = 8041  wps
# step = 800.0, perplexity = 121.37166695, learning rate = 1.0, speed = 8044  wps
# step = 1000.0, perplexity = 120.518967399, learning rate = 1.0, speed = 8035  wps
# step = 1200.0, perplexity = 118.223363445, learning rate = 1.0, speed = 8037  wps
# step = 1400.0, perplexity = 116.063291179, learning rate = 1.0, speed = 8040  wps
# epoch  3: perplexity = 115.453521441, learning rate = 1.0
# Validation set perplexity = 261.879067776
# Test set perplexity = 271.928847337
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 111.661008874, learning rate = 1.0, speed = 7979  wps
# step = 400.0, perplexity = 105.846729805, learning rate = 1.0, speed = 8011  wps
# step = 600.0, perplexity = 104.516841016, learning rate = 1.0, speed = 8021  wps
# step = 800.0, perplexity = 103.60508624, learning rate = 1.0, speed = 8027  wps
# step = 1000.0, perplexity = 103.374648714, learning rate = 1.0, speed = 8025  wps
# step = 1200.0, perplexity = 101.804285077, learning rate = 1.0, speed = 8029  wps
# step = 1400.0, perplexity = 100.367200946, learning rate = 1.0, speed = 8034  wps
# epoch  4: perplexity = 99.9080473202, learning rate = 1.0
# Validation set perplexity = 241.944712989
# Test set perplexity = 252.448904985
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 99.4153124075, learning rate = 1.0, speed = 7980  wps
# step = 400.0, perplexity = 94.4189068351, learning rate = 1.0, speed = 8012  wps
# step = 600.0, perplexity = 93.6580160917, learning rate = 1.0, speed = 8022  wps
# step = 800.0, perplexity = 93.0337683912, learning rate = 1.0, speed = 8027  wps
# step = 1000.0, perplexity = 93.0508951737, learning rate = 1.0, speed = 8026  wps
# step = 1200.0, perplexity = 91.8764450125, learning rate = 1.0, speed = 8030  wps
# step = 1400.0, perplexity = 90.7709149081, learning rate = 1.0, speed = 8033  wps
# epoch  5: perplexity = 90.3984866981, learning rate = 1.0
# Validation set perplexity = 233.897348918
# Test set perplexity = 243.444080247
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 91.4212040319, learning rate = 1.0, speed = 7983  wps
# step = 400.0, perplexity = 86.8924566219, learning rate = 1.0, speed = 8013  wps
# step = 600.0, perplexity = 86.3460537776, learning rate = 1.0, speed = 8024  wps
# step = 800.0, perplexity = 85.9058939619, learning rate = 1.0, speed = 8028  wps
# step = 1000.0, perplexity = 85.9385303344, learning rate = 1.0, speed = 8024  wps
# step = 1200.0, perplexity = 84.977704077, learning rate = 1.0, speed = 8028  wps
# step = 1400.0, perplexity = 84.0482240497, learning rate = 1.0, speed = 8033  wps
# epoch  6: perplexity = 83.7119169568, learning rate = 1.0
# Validation set perplexity = 222.84418979
# Test set perplexity = 232.52488624
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 85.5498162933, learning rate = 1.0, speed = 7981  wps
# step = 400.0, perplexity = 81.2205645721, learning rate = 1.0, speed = 8016  wps
# step = 600.0, perplexity = 80.8490855692, learning rate = 1.0, speed = 8026  wps
# step = 800.0, perplexity = 80.4798449519, learning rate = 1.0, speed = 8030  wps
# step = 1000.0, perplexity = 80.6863588428, learning rate = 1.0, speed = 8027  wps
# step = 1200.0, perplexity = 79.8516642029, learning rate = 1.0, speed = 8031  wps
# step = 1400.0, perplexity = 79.0323061772, learning rate = 1.0, speed = 8036  wps
# epoch  7: perplexity = 78.7361292485, learning rate = 1.0
# Validation set perplexity = 216.860264546
# Test set perplexity = 227.220552448
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 80.98465176, learning rate = 1.0, speed = 7980  wps
# step = 400.0, perplexity = 77.1477816899, learning rate = 1.0, speed = 8010  wps
# step = 600.0, perplexity = 76.6685478251, learning rate = 1.0, speed = 8021  wps
# step = 800.0, perplexity = 76.371792775, learning rate = 1.0, speed = 8026  wps
# step = 1000.0, perplexity = 76.5990858936, learning rate = 1.0, speed = 8025  wps
# step = 1200.0, perplexity = 75.8532967203, learning rate = 1.0, speed = 8025  wps
# step = 1400.0, perplexity = 75.1364297632, learning rate = 1.0, speed = 8029  wps
# epoch  8: perplexity = 74.8606893204, learning rate = 1.0
# Validation set perplexity = 210.575175387
# Test set perplexity = 220.07945879
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 77.2245466276, learning rate = 1.0, speed = 7979  wps
# step = 400.0, perplexity = 73.4863641828, learning rate = 1.0, speed = 8007  wps
# step = 600.0, perplexity = 73.2189864419, learning rate = 1.0, speed = 8016  wps
# step = 800.0, perplexity = 72.9671147798, learning rate = 1.0, speed = 8015  wps
# step = 1000.0, perplexity = 73.2829610711, learning rate = 1.0, speed = 8013  wps
# step = 1200.0, perplexity = 72.6455176103, learning rate = 1.0, speed = 8017  wps
# step = 1400.0, perplexity = 71.9712354908, learning rate = 1.0, speed = 8023  wps
# epoch  9: perplexity = 71.7331871301, learning rate = 1.0
# Validation set perplexity = 206.708064284
# Test set perplexity = 216.612762526
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 74.2060919149, learning rate = 1.0, speed = 7963  wps
# step = 400.0, perplexity = 70.7253575005, learning rate = 1.0, speed = 7998  wps
# step = 600.0, perplexity = 70.3846398061, learning rate = 1.0, speed = 8010  wps
# step = 800.0, perplexity = 70.2245337987, learning rate = 1.0, speed = 8016  wps
# step = 1000.0, perplexity = 70.5220402492, learning rate = 1.0, speed = 8014  wps
# step = 1200.0, perplexity = 69.9272497526, learning rate = 1.0, speed = 8017  wps
# step = 1400.0, perplexity = 69.3577904497, learning rate = 1.0, speed = 8023  wps
# epoch  10: perplexity = 69.1284693654, learning rate = 1.0
# Validation set perplexity = 199.234369994
# Test set perplexity = 208.491880623
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 71.3008436343, learning rate = 1.0, speed = 7973  wps
# step = 400.0, perplexity = 68.1147587877, learning rate = 1.0, speed = 8002  wps
# step = 600.0, perplexity = 67.8933733722, learning rate = 1.0, speed = 8013  wps
# step = 800.0, perplexity = 67.7780012826, learning rate = 1.0, speed = 8016  wps
# step = 1000.0, perplexity = 68.0651992528, learning rate = 1.0, speed = 8012  wps
# step = 1200.0, perplexity = 67.5049800388, learning rate = 1.0, speed = 8015  wps
# step = 1400.0, perplexity = 66.9161308314, learning rate = 1.0, speed = 8019  wps
# epoch  11: perplexity = 66.7080571705, learning rate = 1.0
# Validation set perplexity = 200.07317151
# Test set perplexity = 210.473298507
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 66.7149708302, learning rate = 0.5, speed = 7974  wps
# step = 400.0, perplexity = 62.9929599421, learning rate = 0.5, speed = 8002  wps
# step = 600.0, perplexity = 62.1673172017, learning rate = 0.5, speed = 8006  wps
# step = 800.0, perplexity = 61.5854538339, learning rate = 0.5, speed = 8012  wps
# step = 1000.0, perplexity = 61.5081321602, learning rate = 0.5, speed = 8011  wps
# step = 1200.0, perplexity = 60.6843340971, learning rate = 0.5, speed = 8015  wps
# step = 1400.0, perplexity = 59.8525633793, learning rate = 0.5, speed = 8020  wps
# epoch  12: perplexity = 59.61116876, learning rate = 0.5
# Validation set perplexity = 193.01650824
# Test set perplexity = 204.366137508
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 61.9490278716, learning rate = 0.5, speed = 7965  wps
# step = 400.0, perplexity = 58.9449601881, learning rate = 0.5, speed = 7995  wps
# step = 600.0, perplexity = 58.6155168998, learning rate = 0.5, speed = 8009  wps
# step = 800.0, perplexity = 58.3645489314, learning rate = 0.5, speed = 8015  wps
# step = 1000.0, perplexity = 58.4904459758, learning rate = 0.5, speed = 8015  wps
# step = 1200.0, perplexity = 57.8800637242, learning rate = 0.5, speed = 8019  wps
# step = 1400.0, perplexity = 57.3060760561, learning rate = 0.5, speed = 8023  wps
# epoch  13: perplexity = 57.1084255388, learning rate = 0.5
# Validation set perplexity = 191.690310274
# Test set perplexity = 202.124199751
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 59.7830312126, learning rate = 0.5, speed = 7977  wps
# step = 400.0, perplexity = 57.0041647097, learning rate = 0.5, speed = 8005  wps
# step = 600.0, perplexity = 56.7284395411, learning rate = 0.5, speed = 8018  wps
# step = 800.0, perplexity = 56.5717511308, learning rate = 0.5, speed = 8021  wps
# step = 1000.0, perplexity = 56.7470102646, learning rate = 0.5, speed = 8016  wps
# step = 1200.0, perplexity = 56.2515718116, learning rate = 0.5, speed = 8021  wps
# step = 1400.0, perplexity = 55.7107608611, learning rate = 0.5, speed = 8027  wps
# epoch  14: perplexity = 55.5328636673, learning rate = 0.5
# Validation set perplexity = 189.573030615
# Test set perplexity = 200.015865731
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 58.4676202462, learning rate = 0.5, speed = 7968  wps
# step = 400.0, perplexity = 55.7823751843, learning rate = 0.5, speed = 7990  wps
# step = 600.0, perplexity = 55.5456904459, learning rate = 0.5, speed = 8005  wps
# step = 800.0, perplexity = 55.3875468647, learning rate = 0.5, speed = 8011  wps
# step = 1000.0, perplexity = 55.5994639975, learning rate = 0.5, speed = 8010  wps
# step = 1200.0, perplexity = 55.0934288267, learning rate = 0.5, speed = 8013  wps
# step = 1400.0, perplexity = 54.5938858923, learning rate = 0.5, speed = 8016  wps
# epoch  15: perplexity = 54.421961311, learning rate = 0.5
# Validation set perplexity = 186.935350969
# Test set perplexity = 197.693924675
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 57.3209545886, learning rate = 0.5, speed = 7972  wps
# step = 400.0, perplexity = 54.5590406116, learning rate = 0.5, speed = 8001  wps
# step = 600.0, perplexity = 54.3723491848, learning rate = 0.5, speed = 8013  wps
# step = 800.0, perplexity = 54.2509044733, learning rate = 0.5, speed = 8018  wps
# step = 1000.0, perplexity = 54.4486626213, learning rate = 0.5, speed = 8004  wps
# step = 1200.0, perplexity = 53.9972157443, learning rate = 0.5, speed = 8006  wps
# step = 1400.0, perplexity = 53.5333427916, learning rate = 0.5, speed = 8009  wps
# epoch  16: perplexity = 53.3749147766, learning rate = 0.5
# Validation set perplexity = 187.210473725
# Test set perplexity = 198.27872486
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 55.2919883736, learning rate = 0.25, speed = 7969  wps
# step = 400.0, perplexity = 52.4225318235, learning rate = 0.25, speed = 8001  wps
# step = 600.0, perplexity = 52.0138387811, learning rate = 0.25, speed = 8014  wps
# step = 800.0, perplexity = 51.6894943142, learning rate = 0.25, speed = 8014  wps
# step = 1000.0, perplexity = 51.6696361296, learning rate = 0.25, speed = 8013  wps
# step = 1200.0, perplexity = 51.0296076671, learning rate = 0.25, speed = 8017  wps
# step = 1400.0, perplexity = 50.4106147606, learning rate = 0.25, speed = 8016  wps
# epoch  17: perplexity = 50.2327673693, learning rate = 0.25
# Validation set perplexity = 185.160927596
# Test set perplexity = 196.438299349
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 53.1843693994, learning rate = 0.25, speed = 7957  wps
# step = 400.0, perplexity = 50.6201670755, learning rate = 0.25, speed = 7985  wps
# step = 600.0, perplexity = 50.2897117402, learning rate = 0.25, speed = 8003  wps
# step = 800.0, perplexity = 50.0622443355, learning rate = 0.25, speed = 8010  wps
# step = 1000.0, perplexity = 50.1726418386, learning rate = 0.25, speed = 8008  wps
# step = 1200.0, perplexity = 49.6984853321, learning rate = 0.25, speed = 8014  wps
# step = 1400.0, perplexity = 49.1750046411, learning rate = 0.25, speed = 8019  wps
# epoch  18: perplexity = 49.029420277, learning rate = 0.25
# Validation set perplexity = 186.052185499
# Test set perplexity = 197.459343028
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 52.0597273641, learning rate = 0.125, speed = 7968  wps
# step = 400.0, perplexity = 49.5165821711, learning rate = 0.125, speed = 7995  wps
# step = 600.0, perplexity = 49.1296768377, learning rate = 0.125, speed = 8009  wps
# step = 800.0, perplexity = 48.8418266087, learning rate = 0.125, speed = 8014  wps
# step = 1000.0, perplexity = 48.8560768825, learning rate = 0.125, speed = 8012  wps
# step = 1200.0, perplexity = 48.2933081327, learning rate = 0.125, speed = 8014  wps
# step = 1400.0, perplexity = 47.7073652527, learning rate = 0.125, speed = 8015  wps
# epoch  19: perplexity = 47.5487146456, learning rate = 0.125
# Validation set perplexity = 186.836321713
# Test set perplexity = 198.938864369
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 50.8748347258, learning rate = 0.0625, speed = 7971  wps
# step = 400.0, perplexity = 48.5609682762, learning rate = 0.0625, speed = 8003  wps
