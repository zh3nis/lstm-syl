# %%
import numpy as np
import tensorflow as tf
import time
from pyphen import Pyphen

# %%
# Global hyperparameters
batch_size = 20
max_grad_norm = 5
lr_decay = 0.5
learning_rate = 1.0
init_scale = 0.05

# LSTM hyperparameters
num_steps = 35
hidden_size = 300
num_layers = 2
keep_prob = 0.5

# Syllable LSTM hyperparameters
#syl_emb_dim = 100
#syl_hidden_size = 150
#max_word_len - number of steps (syllables) to unroll the syllable LSTM for, will be defined based on training data

# %%
# possibles languages: ptb, fr, es, de, cs, ru ('ptb' means English PTB dataset)
lang = 'es'

pyphen_lang = {'ptb': 'en_US',
               'fr': 'fr_FR',
               'es': 'es',
               'de': 'de_DE',
               'cs': 'cs_CZ',
               'ru': 'ru_RU'}

if lang == 'ptb': 
  word_data = open('simple-examples/data/ptb.train.txt', 'r').read().replace('\n', '<eos>').split()
else:
  word_data = open('data/'+lang+'/train.txt', 'r').read().replace('\n', ' ').split()

words = list(set(word_data))
word_data_size, word_vocab_size = len(word_data), len(words)
print('data has %d words, %d unique' % (word_data_size, word_vocab_size))

word_to_ix = { word:i for i,word in enumerate(words) }
ix_to_word = { i:word for i,word in enumerate(words) }

def get_word_raw_data(input_file):
  if lang == 'ptb':
    data = open(input_file, 'r').read().replace('\n', '<eos>').split()
  else:
    data = open(input_file, 'r').read().replace('\n', ' ').split()
  return [word_to_ix[w] for w in data if w in word_to_ix]

train_raw_data = get_word_raw_data('data/'+lang+'/train.txt')
valid_raw_data = get_word_raw_data('data/'+lang+'/valid.txt')
test_raw_data = get_word_raw_data('data/'+lang+'/test.txt')
# Out:
# data has 1000029 words, 27010 unique

# %%
hyphenator = Pyphen(lang=pyphen_lang[lang])

def my_syllables(word):
  return hyphenator.inserted(word).split('-')

syllables = set()
word_lens_in_syl = []

for word in words:
  syls = my_syllables(word)
  word_lens_in_syl.append(len(syls))
  for syl in syls:
    syllables.add(syl)

syls_list = list(syllables)
syl_vocab_size = len(syls_list)

max_word_len = int(np.percentile(word_lens_in_syl, 97))
print('data has %d unique syllables' % syl_vocab_size)
print('max word length in syllables is set to', max_word_len)

#one more fake syllable for zero-padding
zero_pad_syl = ' '
syls_list.insert(0, zero_pad_syl)
syl_vocab_size += 1

syl_to_ix = { syl:i for i,syl in enumerate(syls_list) }
ix_to_syl = { i:syl for i,syl in enumerate(syls_list) }


def get_syl_hyperparams(total):
  a = 4 * (1.5 + 1.5 * 1.5)
  b = syl_vocab_size + 4 * 1.5 + 4 * 1.5 * hidden_size
  c = 4 * (hidden_size * hidden_size + hidden_size) +\
      4 * (hidden_size * hidden_size + hidden_size * hidden_size + hidden_size) +\
      hidden_size * word_vocab_size + word_vocab_size - total
  neg, pos = np.roots([a, b, c])
  return (int(round(pos)), int(round(1.5 * pos)))

total = {'ptb': 5310115,
         'fr': 9820689,
         'es': 10430455,
         'de': 13317075,
         'cs': 16251327,
         'ru': 21353640}

syl_emb_dim, syl_hidden_size = get_syl_hyperparams(total[lang])
print('Syllable embedding size: ', syl_emb_dim)
print('Syllable LSTM hidden size: ', syl_hidden_size)
# Out:
# data has 4227 unique syllables
# max word length in syllables is set to 6
# Syllable embedding size:  148
# Syllable LSTM hidden size:  221

# %%
def word_ix_to_syl_ixs(word_ix):
  word = ix_to_word[word_ix]
  word_in_syls = my_syllables(word)
  if len(word_in_syls) > max_word_len:
    del word_in_syls[max_word_len:]
  else:
    word_in_syls += [zero_pad_syl] * (max_word_len - len(word_in_syls))
  return [syl_to_ix[syl] for syl in word_in_syls]

constitution = {'ptb': 'constitution', 
                'fr': 'constitution', 
                'de': 'verfassung', 
                'cs': 'ústava',
                'es': 'constitución',
                'ru': 'конституция'}
print('-'.join(ix_to_syl[syl_ix] for syl_ix in word_ix_to_syl_ixs(word_to_ix[constitution[lang]])))
# Out:
# cons-ti-tu-ción- -

# %%
class batch_producer(object):
  def __init__(self, raw_data, batch_size, num_steps):
    self.raw_data = raw_data
    self.batch_size = batch_size
    self.num_steps = num_steps
    
    self.batch_len = len(self.raw_data) // self.batch_size
    self.data = np.reshape(self.raw_data[0 : self.batch_size * self.batch_len],
                           (self.batch_size, self.batch_len))
    
    self.epoch_size = (self.batch_len - 1) // self.num_steps
    self.i = 0
  
  def __next__(self):
    if self.i < self.epoch_size:
      # batch_x and batch_y are of shape [batch_size, num_steps]
      batch_x = self.data[::, self.i * self.num_steps : (self.i + 1) * self.num_steps : ]
      batch_y = self.data[::, self.i * self.num_steps + 1 : (self.i + 1) * self.num_steps + 1 : ]
      self.i += 1
      return (batch_x, batch_y)
    else:
      raise StopIteration()

  def __iter__(self):
    return self

# %%
class Model:
  
  syl_embedding = tf.get_variable("syl_embedding", [syl_vocab_size, syl_emb_dim], dtype=tf.float32,
                                  initializer=tf.random_uniform_initializer(-init_scale, init_scale))
  syl_lstm_cell = tf.nn.rnn_cell.LSTMCell(syl_hidden_size, forget_bias=0.0)
  cell = tf.nn.rnn_cell.LSTMCell(hidden_size, forget_bias=0.0)
  
  def __init__(self, batch_size, need_reuse=False):
    self.x = tf.placeholder(tf.int32, [batch_size, num_steps, max_word_len])
    self.y = tf.placeholder(tf.int32, [batch_size, num_steps])
    
    words_embedded = tf.nn.embedding_lookup(self.syl_embedding, self.x)
    words_emb_as_list = tf.unpack(words_embedded, axis=1)

    syl_init_state = self.syl_lstm_cell.zero_state(batch_size, dtype=tf.float32)

    lstm_input = []
    reuse_syl_lstm = need_reuse
    for word_emb in words_emb_as_list:
      #list of max_word_len elements of [batch_size, syl_emb_dim]
      word_in_syls = tf.unpack(word_emb, axis=1)
      with tf.variable_scope('syl_lstm', reuse=reuse_syl_lstm):
        syl_outputs, syl_state = tf.nn.rnn(self.syl_lstm_cell, word_in_syls, dtype=tf.float32, 
                                           initial_state=syl_init_state, sequence_length=self.length(word_emb))
      lstm_input.append(syl_state.h)
      reuse_syl_lstm = True
    
    self.apply_dropout()
    self.cell = tf.nn.rnn_cell.MultiRNNCell([self.cell] * num_layers)
    
    self.init_state = self.cell.zero_state(batch_size, dtype=tf.float32)
    with tf.variable_scope('lstm_rnn', reuse=need_reuse):
      outputs, self.state = tf.nn.rnn(self.cell, lstm_input, dtype=tf.float32, initial_state=self.init_state)

    with tf.variable_scope('softmax_params', reuse=need_reuse):
      weights = tf.get_variable('weights', [hidden_size, word_vocab_size], 
                                initializer=tf.random_uniform_initializer(-init_scale, init_scale), 
                                dtype=tf.float32)
      biases = tf.get_variable('biases', [word_vocab_size], 
                               initializer=tf.random_uniform_initializer(-init_scale, init_scale),
                               dtype=tf.float32)

    output = tf.reshape(tf.concat(1, outputs), [-1, hidden_size])
    logits = tf.matmul(output, weights) + biases
    loss = tf.nn.seq2seq.sequence_loss_by_example(
            [logits],
            [tf.reshape(self.y, [-1])],
            [tf.ones([batch_size * num_steps], dtype=tf.float32)])
    self.cost = tf.reduce_sum(loss) / batch_size

  def length(self, sequence):
    used = tf.sign(tf.reduce_max(tf.abs(sequence), reduction_indices=2))
    length = tf.reduce_sum(used, reduction_indices=1)
    length = tf.cast(length, tf.int32)
    return length
  
  def apply_dropout(self):
    self.cell = tf.nn.rnn_cell.DropoutWrapper(self.cell, output_keep_prob=keep_prob)
    self.syl_lstm_cell = tf.nn.rnn_cell.DropoutWrapper(self.syl_lstm_cell, input_keep_prob=keep_prob, 
                                                       output_keep_prob=keep_prob)

# %%
class Train(Model):
  
  def __init__(self, batch_size):
    self.clear_syl_embedding_padding = tf.scatter_update(self.syl_embedding, 
                                                         [0], 
                                                         tf.constant(0.0, shape=[1, syl_emb_dim], dtype=tf.float32)
                                                        )
  
    super(Train, self).__init__(batch_size)
    
    self.lr = tf.Variable(0.0, trainable=False, dtype=tf.float32)
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(self.cost, tvars), max_grad_norm)
    optimizer = tf.train.GradientDescentOptimizer(self.lr)
    self.train_op = optimizer.apply_gradients(zip(grads, tvars),
                                              global_step=tf.contrib.framework.get_or_create_global_step())
    
    self.new_lr = tf.placeholder(tf.float32, shape=[], name="new_learning_rate")
    self.lr_update = tf.assign(self.lr, self.new_lr)

  def assign_lr(self, session, lr_value):
    session.run(self.lr_update, feed_dict={self.new_lr: lr_value})

# %%
class Eval(Model):
  
  def apply_dropout(self):
    pass

# %%
train = Train(batch_size)
valid = Eval(batch_size, need_reuse=True)
test = Eval(1, need_reuse=True)

# %%
def model_size():
  params = tf.trainable_variables()
  size = 0
  for x in params:
    sz = 1
    for dim in x.get_shape():
      sz *= dim.value
    size += sz
  return size

print('Model size is: ', model_size())

def my_model_size():
  return syl_vocab_size * syl_emb_dim +\
         4 * (syl_emb_dim * syl_hidden_size + syl_hidden_size * syl_hidden_size + syl_hidden_size) +\
         4 * (syl_hidden_size * hidden_size + hidden_size * hidden_size + hidden_size) +\
         4 * (hidden_size * hidden_size + hidden_size * hidden_size + hidden_size) +\
         hidden_size * word_vocab_size + word_vocab_size
        
print('My model size: ', my_model_size())
# Out:
# Model size is:  10430434
# My model size:  10430434

# %%
num_epochs = 30
display_freq = 200

init = tf.global_variables_initializer()
with tf.Session() as sess:
  sess.run(init)
  sess.run(train.clear_syl_embedding_padding)
  prev_perplexity = float('inf')
  
  for epoch in range(num_epochs):
    start_time = time.time()
    train.assign_lr(sess, learning_rate)
    
    iters = 0
    costs = 0
    
    train_batches = batch_producer(train_raw_data, batch_size, num_steps)
        
    training_state = None

    for batch in train_batches:
      my_x = np.empty([batch_size, num_steps, max_word_len], dtype=np.int32)

      for t in range(num_steps):
        for i in range(batch_size):
          my_x[i, t] = word_ix_to_syl_ixs(batch[0][i, t])

      if not training_state: training_state = sess.run(train.init_state)
      _, c, training_state, my_lr = sess.run([train.train_op, train.cost, train.state, train.lr],
                                             feed_dict={train.x: my_x, train.y: batch[1], 
                                                        train.init_state: training_state})
      sess.run(train.clear_syl_embedding_padding)
      
      costs += c
      if iters % (display_freq*num_steps) == 0 and iters != 0:
        print('step =', iters/num_steps, end=', ')
        print('perplexity =', np.exp(costs / iters), end=', ')
        print('learning rate =', my_lr, end=', ')
        print('speed =', round(iters * batch_size / (time.time() - start_time)), ' wps')

      iters += num_steps
    
    print('epoch ', epoch+1, end = ': ')
    print('perplexity =', np.exp(costs / iters), end=', ')
    print('learning rate =', my_lr)
    
    
    # Get validation set perplexity
    valid_costs = 0
    valid_state = None
    valid_iters = 0

    valid_batches = batch_producer(valid_raw_data, batch_size, num_steps)
    
    for valid_batch in valid_batches:
      my_valid_x = np.empty([batch_size, num_steps, max_word_len], dtype=np.int32)
      
      for t in range(num_steps):
        for i in range(batch_size):
          my_valid_x[i, t] = word_ix_to_syl_ixs(valid_batch[0][i, t])
      
      if not valid_state: valid_state = sess.run(valid.init_state)
      c, valid_state = sess.run([valid.cost, valid.state], 
                                feed_dict={valid.x: my_valid_x, valid.y: valid_batch[1], 
                                           valid.init_state: valid_state})

      valid_costs += c
      valid_iters += num_steps
    
    cur_perplexity = np.exp(valid_costs / valid_iters)
    print('Validation set perplexity =', cur_perplexity)

    if prev_perplexity - cur_perplexity < 1:
      learning_rate *= lr_decay
    prev_perplexity = cur_perplexity

    
    # Get test set perplexity
    test_costs = 0
    test_state = None
    test_iters = 0

    test_batches = batch_producer(test_raw_data, 1, num_steps)
    
    for test_batch in test_batches:
      my_test_x = np.empty([1, num_steps, max_word_len], dtype=np.int32)
      
      for t in range(num_steps):
        for i in range(1):
          my_test_x[i, t] = word_ix_to_syl_ixs(test_batch[0][i, t])

      if not test_state: test_state = sess.run(test.init_state)
      c, test_state = sess.run([test.cost, test.state], 
                                feed_dict={test.x: my_test_x, test.y: test_batch[1], 
                                           test.init_state: test_state})

      test_costs += c
      test_iters += num_steps
    
    print('Test set perplexity =', np.exp(test_costs / test_iters))
       

    print('-' * 100)
# Out:
# step = 200.0, perplexity = 1473.23350713, learning rate = 1.0, speed = 5644  wps
# step = 400.0, perplexity = 1084.74826197, learning rate = 1.0, speed = 6052  wps
# step = 600.0, perplexity = 826.307512968, learning rate = 1.0, speed = 6176  wps
# step = 800.0, perplexity = 666.986633812, learning rate = 1.0, speed = 6218  wps
# step = 1000.0, perplexity = 561.580653085, learning rate = 1.0, speed = 6256  wps
# step = 1200.0, perplexity = 487.217398545, learning rate = 1.0, speed = 6263  wps
# step = 1400.0, perplexity = 436.610201435, learning rate = 1.0, speed = 6284  wps
# epoch  1: perplexity = 428.714267085, learning rate = 1.0
# Validation set perplexity = 353.159627319
# Test set perplexity = 364.673675391
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 202.598115688, learning rate = 1.0, speed = 6296  wps
# step = 400.0, perplexity = 191.821963911, learning rate = 1.0, speed = 6324  wps
# step = 600.0, perplexity = 183.368896704, learning rate = 1.0, speed = 6358  wps
# step = 800.0, perplexity = 176.858931677, learning rate = 1.0, speed = 6379  wps
# step = 1000.0, perplexity = 171.51065952, learning rate = 1.0, speed = 6391  wps
# step = 1200.0, perplexity = 166.992567463, learning rate = 1.0, speed = 6394  wps
# step = 1400.0, perplexity = 162.359481626, learning rate = 1.0, speed = 6396  wps
# epoch  2: perplexity = 161.36274283, learning rate = 1.0
# Validation set perplexity = 271.715864196
# Test set perplexity = 278.422929183
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 140.589260417, learning rate = 1.0, speed = 6381  wps
# step = 400.0, perplexity = 136.287591868, learning rate = 1.0, speed = 6385  wps
# step = 600.0, perplexity = 132.921700261, learning rate = 1.0, speed = 6354  wps
# step = 800.0, perplexity = 130.57666578, learning rate = 1.0, speed = 6289  wps
# step = 1000.0, perplexity = 128.672284999, learning rate = 1.0, speed = 6280  wps
# step = 1200.0, perplexity = 127.073150744, learning rate = 1.0, speed = 6243  wps
# step = 1400.0, perplexity = 124.941738425, learning rate = 1.0, speed = 6247  wps
# epoch  3: perplexity = 124.369458801, learning rate = 1.0
# Validation set perplexity = 249.382979426
# Test set perplexity = 256.896932108
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 117.927775344, learning rate = 1.0, speed = 6325  wps
# step = 400.0, perplexity = 114.916726345, learning rate = 1.0, speed = 6261  wps
# step = 600.0, perplexity = 112.772072838, learning rate = 1.0, speed = 6267  wps
# step = 800.0, perplexity = 111.595378962, learning rate = 1.0, speed = 6311  wps
# step = 1000.0, perplexity = 110.49942835, learning rate = 1.0, speed = 6335  wps
# step = 1200.0, perplexity = 109.770176709, learning rate = 1.0, speed = 6349  wps
# step = 1400.0, perplexity = 108.337071088, learning rate = 1.0, speed = 6354  wps
# epoch  4: perplexity = 107.899004719, learning rate = 1.0
# Validation set perplexity = 230.731185594
# Test set perplexity = 237.003755969
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 105.194703639, learning rate = 1.0, speed = 5862  wps
# step = 400.0, perplexity = 103.112979779, learning rate = 1.0, speed = 5990  wps
# step = 600.0, perplexity = 101.614219064, learning rate = 1.0, speed = 6042  wps
# step = 800.0, perplexity = 100.832633374, learning rate = 1.0, speed = 6099  wps
# step = 1000.0, perplexity = 100.19850898, learning rate = 1.0, speed = 6158  wps
# step = 1200.0, perplexity = 99.6559842439, learning rate = 1.0, speed = 6197  wps
# step = 1400.0, perplexity = 98.4969227473, learning rate = 1.0, speed = 6219  wps
# epoch  5: perplexity = 98.1361335849, learning rate = 1.0
# Validation set perplexity = 217.187195016
# Test set perplexity = 222.987510199
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 96.450073748, learning rate = 1.0, speed = 6097  wps
# step = 400.0, perplexity = 95.0171492524, learning rate = 1.0, speed = 6184  wps
# step = 600.0, perplexity = 93.8131376284, learning rate = 1.0, speed = 6184  wps
# step = 800.0, perplexity = 93.3484354905, learning rate = 1.0, speed = 6187  wps
# step = 1000.0, perplexity = 92.8664154887, learning rate = 1.0, speed = 6214  wps
# step = 1200.0, perplexity = 92.5878480679, learning rate = 1.0, speed = 6216  wps
# step = 1400.0, perplexity = 91.6716264813, learning rate = 1.0, speed = 6240  wps
# epoch  6: perplexity = 91.3444895072, learning rate = 1.0
# Validation set perplexity = 207.930910246
# Test set perplexity = 214.165560434
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 90.8022770766, learning rate = 1.0, speed = 6269  wps
# step = 400.0, perplexity = 89.5977496861, learning rate = 1.0, speed = 6199  wps
# step = 600.0, perplexity = 88.4816294047, learning rate = 1.0, speed = 6038  wps
# step = 800.0, perplexity = 88.19852148, learning rate = 1.0, speed = 6072  wps
# step = 1000.0, perplexity = 87.7697656709, learning rate = 1.0, speed = 6129  wps
# step = 1200.0, perplexity = 87.5809075535, learning rate = 1.0, speed = 6163  wps
# step = 1400.0, perplexity = 86.7332563015, learning rate = 1.0, speed = 6183  wps
# epoch  7: perplexity = 86.4317064831, learning rate = 1.0
# Validation set perplexity = 203.76817591
# Test set perplexity = 210.071073408
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 86.1748849769, learning rate = 1.0, speed = 6166  wps
# step = 400.0, perplexity = 84.9455734388, learning rate = 1.0, speed = 6128  wps
# step = 600.0, perplexity = 84.0476393395, learning rate = 1.0, speed = 6051  wps
# step = 800.0, perplexity = 83.7945591278, learning rate = 1.0, speed = 6067  wps
# step = 1000.0, perplexity = 83.4938577365, learning rate = 1.0, speed = 6043  wps
# step = 1200.0, perplexity = 83.4132593598, learning rate = 1.0, speed = 6052  wps
# step = 1400.0, perplexity = 82.6433590054, learning rate = 1.0, speed = 6076  wps
# epoch  8: perplexity = 82.3653609964, learning rate = 1.0
# Validation set perplexity = 194.654613144
# Test set perplexity = 200.507889464
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 82.6479442138, learning rate = 1.0, speed = 6113  wps
# step = 400.0, perplexity = 81.6480753976, learning rate = 1.0, speed = 6176  wps
# step = 600.0, perplexity = 80.892167374, learning rate = 1.0, speed = 6233  wps
# step = 800.0, perplexity = 80.6875921829, learning rate = 1.0, speed = 6273  wps
# step = 1000.0, perplexity = 80.3792331697, learning rate = 1.0, speed = 6300  wps
# step = 1200.0, perplexity = 80.3471966871, learning rate = 1.0, speed = 6314  wps
# step = 1400.0, perplexity = 79.6307620373, learning rate = 1.0, speed = 6325  wps
# epoch  9: perplexity = 79.3602088189, learning rate = 1.0
# Validation set perplexity = 189.93935601
# Test set perplexity = 195.85403634
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 79.8124885631, learning rate = 1.0, speed = 6388  wps
# step = 400.0, perplexity = 78.7509068143, learning rate = 1.0, speed = 6415  wps
# step = 600.0, perplexity = 78.0307118125, learning rate = 1.0, speed = 6417  wps
# step = 800.0, perplexity = 77.8787539533, learning rate = 1.0, speed = 6419  wps
# step = 1000.0, perplexity = 77.6677907247, learning rate = 1.0, speed = 6419  wps
# step = 1200.0, perplexity = 77.5996983374, learning rate = 1.0, speed = 6415  wps
# step = 1400.0, perplexity = 76.9489983364, learning rate = 1.0, speed = 6409  wps
# epoch  10: perplexity = 76.6831062384, learning rate = 1.0
# Validation set perplexity = 187.39288889
# Test set perplexity = 193.004644708
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 77.2796561397, learning rate = 1.0, speed = 6386  wps
# step = 400.0, perplexity = 76.3922603631, learning rate = 1.0, speed = 6358  wps
# step = 600.0, perplexity = 75.6457628122, learning rate = 1.0, speed = 6322  wps
# step = 800.0, perplexity = 75.5103793759, learning rate = 1.0, speed = 6296  wps
# step = 1000.0, perplexity = 75.2925544736, learning rate = 1.0, speed = 6286  wps
# step = 1200.0, perplexity = 75.2421708456, learning rate = 1.0, speed = 6288  wps
# step = 1400.0, perplexity = 74.6143139931, learning rate = 1.0, speed = 6263  wps
# epoch  11: perplexity = 74.394868295, learning rate = 1.0
# Validation set perplexity = 188.3956499
# Test set perplexity = 194.333050584
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 72.1274939746, learning rate = 0.5, speed = 6322  wps
# step = 400.0, perplexity = 70.6262973993, learning rate = 0.5, speed = 6275  wps
# step = 600.0, perplexity = 69.3333255013, learning rate = 0.5, speed = 6252  wps
# step = 800.0, perplexity = 68.8276537525, learning rate = 0.5, speed = 6254  wps
# step = 1000.0, perplexity = 68.1511462586, learning rate = 0.5, speed = 6285  wps
# step = 1200.0, perplexity = 67.7202789996, learning rate = 0.5, speed = 6298  wps
# step = 1400.0, perplexity = 66.7714429927, learning rate = 0.5, speed = 6297  wps
# epoch  12: perplexity = 66.5149654699, learning rate = 0.5
# Validation set perplexity = 178.186587654
# Test set perplexity = 183.364316941
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 67.1209685821, learning rate = 0.5, speed = 6035  wps
# step = 400.0, perplexity = 66.0758493149, learning rate = 0.5, speed = 6158  wps
# step = 600.0, perplexity = 65.3151503951, learning rate = 0.5, speed = 6221  wps
# step = 800.0, perplexity = 65.1350444217, learning rate = 0.5, speed = 6250  wps
# step = 1000.0, perplexity = 64.7740119658, learning rate = 0.5, speed = 6256  wps
# step = 1200.0, perplexity = 64.5816305164, learning rate = 0.5, speed = 6273  wps
# step = 1400.0, perplexity = 63.8930410707, learning rate = 0.5, speed = 6292  wps
# epoch  13: perplexity = 63.6851070968, learning rate = 0.5
# Validation set perplexity = 174.632398828
# Test set perplexity = 179.478056173
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 64.8099014255, learning rate = 0.5, speed = 6310  wps
# step = 400.0, perplexity = 63.9966213214, learning rate = 0.5, speed = 6391  wps
# step = 600.0, perplexity = 63.3216946037, learning rate = 0.5, speed = 6408  wps
# step = 800.0, perplexity = 63.1929749386, learning rate = 0.5, speed = 6433  wps
# step = 1000.0, perplexity = 62.9301256858, learning rate = 0.5, speed = 6454  wps
# step = 1200.0, perplexity = 62.7865948427, learning rate = 0.5, speed = 6456  wps
# step = 1400.0, perplexity = 62.1657949787, learning rate = 0.5, speed = 6463  wps
# epoch  14: perplexity = 61.9596425317, learning rate = 0.5
# Validation set perplexity = 174.513178484
# Test set perplexity = 179.645987138
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 62.6669519369, learning rate = 0.25, speed = 6492  wps
# step = 400.0, perplexity = 61.5103886319, learning rate = 0.25, speed = 6486  wps
# step = 600.0, perplexity = 60.6465093012, learning rate = 0.25, speed = 6499  wps
# step = 800.0, perplexity = 60.2531846745, learning rate = 0.25, speed = 6504  wps
# step = 1000.0, perplexity = 59.7426813724, learning rate = 0.25, speed = 6502  wps
# step = 1200.0, perplexity = 59.4292776981, learning rate = 0.25, speed = 6478  wps
# step = 1400.0, perplexity = 58.6007096759, learning rate = 0.25, speed = 6468  wps
# epoch  15: perplexity = 58.4058444386, learning rate = 0.25
# Validation set perplexity = 169.934764159
# Test set perplexity = 175.170877171
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 59.9753521873, learning rate = 0.25, speed = 6427  wps
# step = 400.0, perplexity = 59.1518770577, learning rate = 0.25, speed = 6486  wps
# step = 600.0, perplexity = 58.4563352115, learning rate = 0.25, speed = 6501  wps
# step = 800.0, perplexity = 58.277731666, learning rate = 0.25, speed = 6517  wps
# step = 1000.0, perplexity = 57.8869937119, learning rate = 0.25, speed = 6502  wps
# step = 1200.0, perplexity = 57.7184962378, learning rate = 0.25, speed = 6489  wps
# step = 1400.0, perplexity = 57.0254097114, learning rate = 0.25, speed = 6492  wps
# epoch  16: perplexity = 56.830403923, learning rate = 0.25
# Validation set perplexity = 168.231917159
# Test set perplexity = 173.45550046
# ----------------------------------------------------------------------------------------------------
# step = 200.0, perplexity = 58.5122687549, learning rate = 0.25, speed = 6127  wps
# step = 400.0, perplexity = 57.8754965722, learning rate = 0.25, speed = 6185  wps
# step = 600.0, perplexity = 57.2597490963, learning rate = 0.25, speed = 6256  wps
# step = 800.0, perplexity = 57.1209908473, learning rate = 0.25, speed = 6294  wps
# step = 1000.0, perplexity = 56.8116183501, learning rate = 0.25, speed = 6327  wps
# step = 1200.0, perplexity = 56.6472067014, learning rate = 0.25, speed = 6354  wps
# step = 1400.0, perplexity = 56.0270679794, learning rate = 0.25, speed = 6375  wps
# epoch  17: perplexity = 55.85635373, learning rate = 0.25
# Validation set perplexity = 165.957573803
